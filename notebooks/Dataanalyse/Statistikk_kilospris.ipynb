# %%
# Sammenligning av kilosprisutvikling for fersk og frosset laks, samt utvikling i prisforskjell

import requests
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Henter og prosesserer data fra SSB
def hent_eksportdata():
    url = "https://data.ssb.no/api/v0/no/table/03024/"
    query = {
        "query": [],
        "response": {"format": "json-stat2"}
    }
    r = requests.post(url, json=query)
    data = r.json()

    from itertools import product
    dims = list(data["dimension"].keys())
    values = data["value"]
    dim_vals = [list(data["dimension"][d]["category"]["label"].values()) for d in dims]
    combos = list(product(*dim_vals))
    df = pd.DataFrame(combos, columns=dims)
    df["Value"] = values
    df_pivot = df.pivot_table(index="Tid", columns=["VareGrupper2", "ContentsCode"],
                               values="Value", aggfunc="sum").reset_index()
    df_pivot.columns = ["År og ukenr.", "Fersk laks - Kilospris", "Fersk laks - Vekt (tonn)",
                        "Frosset laks - Kilospris", "Frosset laks - Vekt (tonn)"]
    df_pivot["UkeID"] = df_pivot["År og ukenr."].str.replace("U", "-")
    return df_pivot

# Sammenligning og utvikling i prisforskjell
def analyser_fersk_vs_frosset_plot():
    df = hent_eksportdata()
    df = df.dropna()

    # Konverter ukeID til mandag i hver uke
    df["UkeDato"] = pd.to_datetime(df["UkeID"] + "-1", format="%Y-%W-%w")

    # Plot 1: Sammenligning av prisene for fersk og frosset laks 
    plt.figure(figsize=(12, 6))
    plt.plot(df["UkeDato"], df["Fersk laks - Kilospris"], label="Fersk laks", color="green")
    plt.plot(df["UkeDato"], df["Frosset laks - Kilospris"], label="Frosset laks", color="orange")
    plt.xlabel("År")
    plt.ylabel("Kilospris (kr/kg)")
    plt.title("Kilospris: Fersk vs. Frosset laks")
    plt.legend()
    plt.grid(True)

    ax = plt.gca()
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

    plt.tight_layout()
    plt.show()

    # Plot 2: Prisforskjell mellom fersk og frosset laks
    df["Prisforskjell"] = df["Fersk laks - Kilospris"] - df["Frosset laks - Kilospris"]

    plt.figure(figsize=(12, 5))
    plt.plot(df["UkeDato"], df["Prisforskjell"], color="purple")
    plt.xlabel("År")
    plt.ylabel("Prisforskjell (kr/kg)")
    plt.title("Utvikling i prisforskjell: Fersk – Frosset laks")
    plt.grid(True)

    ax = plt.gca()
    ax.xaxis.set_major_locator(mdates.YearLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    analyser_fersk_vs_frosset_plot()

# %% [markdown]
# Utfra det første plottet kan vi se at forholdet mellom kilosprisen for både fersk og frosset laks har vært relativt jevn på starten av 2000 tallet, men at den øker og blir mer "ustabil" etter ca. 2016 for begge varetypene, og spesielt variabel etter 2020 og frem til i dag. Dette støttes av plot 2 som viser utviklingen i prisforskjell for både fersk og frosset laks. Grafen er relativt jevn til å begynne med, men blir mer og mer turbulent i de senere årene.
# Vi vil senere undersøke hva grunnen til dette kan være, ved å sammenligne valutakurser med kilospris.

# %%
import requests
import pandas as pd
from itertools import product
from IPython.display import display

# Definerer stil for tabeller
pen_stil = [
    {"selector": "th, td", "props": [("padding", "8px 12px"), ("border", "1px solid #ddd"), ("color", "#000")]},
    {"selector": "th", "props": [("background-color", "#f0f0f0"), ("text-align", "center")]},
    {"selector": "caption", "props": [("caption-side", "top"), ("font-size", "16px"), ("margin-bottom", "10px")]}
]

# Henter og prosesserer data fra SSB
def hent_eksportdata():
    url = "https://data.ssb.no/api/v0/no/table/03024/"
    query = {
        "query": [],
        "response": {"format": "json-stat2"}
    }
    r = requests.post(url, json=query)
    data = r.json()

    dims = list(data["dimension"].keys())
    values = data["value"]
    dim_vals = [list(data["dimension"][d]["category"]["label"].values()) for d in dims]
    combos = list(product(*dim_vals))
    df = pd.DataFrame(combos, columns=dims)
    df["Value"] = values

    df_pivot = df.pivot_table(index="Tid", columns=["VareGrupper2", "ContentsCode"],
                               values="Value", aggfunc="sum").reset_index()
    df_pivot.columns = ["År og ukenr.", "Fersk laks - Kilospris", "Fersk laks - Vekt (tonn)",
                        "Frosset laks - Kilospris", "Frosset laks - Vekt (tonn)"]
    df_pivot["UkeID"] = df_pivot["År og ukenr."].str.replace("U", "-")
    df_pivot["UkeDato"] = pd.to_datetime(df_pivot["UkeID"] + "-1", format="%Y-%W-%w")
    return df_pivot.dropna()

# Statistikk per år (tabellvisning)
def vis_statistikk_per_år(df):
    df["År"] = df["UkeDato"].dt.year

    stats_fersk = df.groupby("År")["Fersk laks - Kilospris"].agg(["mean", "median", "std"]).round(2)
    stats_frosset = df.groupby("År")["Frosset laks - Kilospris"].agg(["mean", "median", "std"]).round(2)

    stats_fersk.columns = ["Gjennomsnitt", "Median", "Std.avvik"]
    stats_frosset.columns = ["Gjennomsnitt", "Median", "Std.avvik"]

    print("\n Statistikk for fersk laks (kr/kg):")
    display(stats_fersk.style
            .set_caption("Fersk laks, per år")
            .format("{:.2f}")
            .background_gradient(cmap="Greens")
            .set_table_styles(pen_stil))

    print("\n Statistikk for frosset laks (kr/kg):")
    display(stats_frosset.style
            .set_caption("Frosset laks, per år")
            .format("{:.2f}")
            .background_gradient(cmap="Blues")
            .set_table_styles(pen_stil))

# Statistikk per sesong (tabellvisning)
def vis_statistikk_per_sesong(df):
    def finn_sesong(mnd):
        if mnd in [3, 4, 5]: return "Vår"
        elif mnd in [6, 7, 8]: return "Sommer"
        elif mnd in [9, 10, 11]: return "Høst"
        else: return "Vinter"

    df["Sesong"] = df["UkeDato"].dt.month.map(finn_sesong)

    stats_fersk = df.groupby("Sesong")["Fersk laks - Kilospris"].agg(["mean", "median", "std"]).round(2)
    stats_frosset = df.groupby("Sesong")["Frosset laks - Kilospris"].agg(["mean", "median", "std"]).round(2)

    stats_fersk.columns = ["Gjennomsnitt", "Median", "Std.avvik"]
    stats_frosset.columns = ["Gjennomsnitt", "Median", "Std.avvik"]

    stats_fersk = stats_fersk.reindex(["Vinter", "Vår", "Sommer", "Høst"])
    stats_frosset = stats_frosset.reindex(["Vinter", "Vår", "Sommer", "Høst"])

    print("\n Statistikk per sesong for fersk laks:")
    display(stats_fersk.style
            .set_caption("Fersk laks, per sesong")
            .format("{:.2f}")
            .background_gradient(cmap="Greens")
            .set_table_styles(pen_stil))

    print("\n Statistikk per sesong for frosset laks:")
    display(stats_frosset.style
            .set_caption("Frosset laks, per sesong")
            .format("{:.2f}")
            .background_gradient(cmap="Blues")
            .set_table_styles(pen_stil))

# Kjør alt
if __name__ == "__main__":
    df = hent_eksportdata()
    vis_statistikk_per_år(df)
    vis_statistikk_per_sesong(df)
# Out:
#  Statistikk for fersk laks (kr/kg):
# <style type="text/css">
# #T_2b959 th {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_2b959  td {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_2b959 th {
#   background-color: #f0f0f0;
#   text-align: center;
# }
# #T_2b959 caption {
#   caption-side: top;
#   font-size: 16px;
#   margin-bottom: 10px;
# }
# #T_2b959_row0_col0 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_2b959_row0_col1, #T_2b959_row6_col0 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_2b959_row0_col2 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_2b959_row1_col0, #T_2b959_row12_col2 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_2b959_row1_col1, #T_2b959_row3_col2, #T_2b959_row5_col0, #T_2b959_row7_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_2b959_row1_col2, #T_2b959_row5_col1, #T_2b959_row5_col2 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_2b959_row2_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_2b959_row2_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_2b959_row2_col2, #T_2b959_row3_col0, #T_2b959_row3_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2b959_row4_col0 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_2b959_row4_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_2b959_row4_col2 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_2b959_row6_col1, #T_2b959_row9_col0 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_2b959_row6_col2 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_2b959_row7_col0, #T_2b959_row7_col2, #T_2b959_row8_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_2b959_row8_col0 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_2b959_row8_col2 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_2b959_row9_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_2b959_row9_col2 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_2b959_row10_col0, #T_2b959_row13_col2 {
#   background-color: #cfecc9;
#   color: #000000;
# }
# #T_2b959_row10_col1 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_2b959_row10_col2 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_2b959_row11_col0 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_2b959_row11_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_2b959_row11_col2 {
#   background-color: #a0d99b;
#   color: #000000;
# }
# #T_2b959_row12_col0, #T_2b959_row12_col1 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_2b959_row13_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2b959_row13_col1 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_2b959_row14_col0 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_2b959_row14_col1 {
#   background-color: #bce4b5;
#   color: #000000;
# }
# #T_2b959_row14_col2 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_2b959_row15_col0, #T_2b959_row15_col1, #T_2b959_row16_col2 {
#   background-color: #bbe4b4;
#   color: #000000;
# }
# #T_2b959_row15_col2 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_2b959_row16_col0, #T_2b959_row18_col1 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_2b959_row16_col1, #T_2b959_row20_col2 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_2b959_row17_col0, #T_2b959_row18_col0 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_2b959_row17_col1 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# #T_2b959_row17_col2 {
#   background-color: #9fd899;
#   color: #000000;
# }
# #T_2b959_row18_col2 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_2b959_row19_col0, #T_2b959_row21_col1 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_2b959_row19_col1 {
#   background-color: #5bb86a;
#   color: #f1f1f1;
# }
# #T_2b959_row19_col2 {
#   background-color: #9bd696;
#   color: #000000;
# }
# #T_2b959_row20_col0 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_2b959_row20_col1 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_2b959_row21_col0 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_2b959_row21_col2 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_2b959_row22_col0 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_2b959_row22_col1 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_2b959_row22_col2 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_2b959_row23_col0, #T_2b959_row23_col1, #T_2b959_row24_col2, #T_2b959_row25_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b959_row23_col2 {
#   background-color: #107a37;
#   color: #f1f1f1;
# }
# #T_2b959_row24_col0 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_2b959_row24_col1 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_2b959_row25_col0 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_2b959_row25_col2 {
#   background-color: #218944;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2b959">
#   <caption>Fersk laks, per år</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b959_level0_col0" class="col_heading level0 col0" >Gjennomsnitt</th>
#       <th id="T_2b959_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_2b959_level0_col2" class="col_heading level0 col2" >Std.avvik</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >År</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b959_level0_row0" class="row_heading level0 row0" >2000</th>
#       <td id="T_2b959_row0_col0" class="data row0 col0" >32.04</td>
#       <td id="T_2b959_row0_col1" class="data row0 col1" >32.33</td>
#       <td id="T_2b959_row0_col2" class="data row0 col2" >3.40</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row1" class="row_heading level0 row1" >2001</th>
#       <td id="T_2b959_row1_col0" class="data row1 col0" >25.99</td>
#       <td id="T_2b959_row1_col1" class="data row1 col1" >26.45</td>
#       <td id="T_2b959_row1_col2" class="data row1 col2" >1.67</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row2" class="row_heading level0 row2" >2002</th>
#       <td id="T_2b959_row2_col0" class="data row2 col0" >23.36</td>
#       <td id="T_2b959_row2_col1" class="data row2 col1" >23.38</td>
#       <td id="T_2b959_row2_col2" class="data row2 col2" >0.70</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row3" class="row_heading level0 row3" >2003</th>
#       <td id="T_2b959_row3_col0" class="data row3 col0" >21.24</td>
#       <td id="T_2b959_row3_col1" class="data row3 col1" >21.75</td>
#       <td id="T_2b959_row3_col2" class="data row3 col2" >1.81</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row4" class="row_heading level0 row4" >2004</th>
#       <td id="T_2b959_row4_col0" class="data row4 col0" >22.55</td>
#       <td id="T_2b959_row4_col1" class="data row4 col1" >22.42</td>
#       <td id="T_2b959_row4_col2" class="data row4 col2" >1.36</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row5" class="row_heading level0 row5" >2005</th>
#       <td id="T_2b959_row5_col0" class="data row5 col0" >26.17</td>
#       <td id="T_2b959_row5_col1" class="data row5 col1" >25.98</td>
#       <td id="T_2b959_row5_col2" class="data row5 col2" >1.70</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row6" class="row_heading level0 row6" >2006</th>
#       <td id="T_2b959_row6_col0" class="data row6 col0" >32.41</td>
#       <td id="T_2b959_row6_col1" class="data row6 col1" >30.92</td>
#       <td id="T_2b959_row6_col2" class="data row6 col2" >5.14</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row7" class="row_heading level0 row7" >2007</th>
#       <td id="T_2b959_row7_col0" class="data row7 col0" >26.68</td>
#       <td id="T_2b959_row7_col1" class="data row7 col1" >26.48</td>
#       <td id="T_2b959_row7_col2" class="data row7 col2" >1.87</td>
#     </tr>
#     <tr>
#       <th id="T_2b959_level0_row8" class="row_heading level0 row8" >2008</th>
#       <td id="T_2b959_row8_col0" class="data row8 col0" >27.02</td>
#       <td id="T_2b959_row8_col1" class="data row8 col1" >26.81</td>
#       <td id="T_2b959_row8_col2" class="data row8 col2" >1.48</td>
#     </tr>
#     <tr
#  Statistikk for frosset laks (kr/kg):
# <style type="text/css">
# #T_5e842 th {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_5e842  td {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_5e842 th {
#   background-color: #f0f0f0;
#   text-align: center;
# }
# #T_5e842 caption {
#   caption-side: top;
#   font-size: 16px;
#   margin-bottom: 10px;
# }
# #T_5e842_row0_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_5e842_row0_col1, #T_5e842_row11_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_5e842_row0_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_5e842_row1_col0, #T_5e842_row5_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_5e842_row1_col1, #T_5e842_row8_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_5e842_row1_col2, #T_5e842_row15_col1 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_5e842_row2_col0, #T_5e842_row2_col1, #T_5e842_row3_col1, #T_5e842_row12_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5e842_row2_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_5e842_row3_col0, #T_5e842_row4_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_5e842_row3_col2, #T_5e842_row4_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_5e842_row4_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_5e842_row5_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_5e842_row5_col2 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_5e842_row6_col0, #T_5e842_row14_col2 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_5e842_row6_col1 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_5e842_row6_col2 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_5e842_row7_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_5e842_row7_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_5e842_row7_col2 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_5e842_row8_col0, #T_5e842_row12_col1 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_5e842_row8_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_5e842_row9_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_5e842_row9_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_5e842_row9_col2 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_5e842_row10_col0 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_5e842_row10_col1, #T_5e842_row13_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_5e842_row10_col2 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_5e842_row11_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_5e842_row11_col2, #T_5e842_row17_col2, #T_5e842_row23_col2 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_5e842_row12_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_5e842_row13_col0 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_5e842_row13_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_5e842_row14_col0, #T_5e842_row14_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_5e842_row15_col0 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_5e842_row15_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_5e842_row16_col0 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_5e842_row16_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_5e842_row16_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_5e842_row17_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_5e842_row17_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_5e842_row18_col0 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_5e842_row18_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_5e842_row18_col2 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_5e842_row19_col0 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_5e842_row19_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_5e842_row19_col2 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_5e842_row20_col0, #T_5e842_row21_col1 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_5e842_row20_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_5e842_row20_col2, #T_5e842_row21_col2 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_5e842_row21_col0 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_5e842_row22_col0 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_5e842_row22_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_5e842_row22_col2, #T_5e842_row23_col0, #T_5e842_row23_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_5e842_row24_col0 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_5e842_row24_col1 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_5e842_row24_col2 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_5e842_row25_col0, #T_5e842_row25_col1 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_5e842_row25_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5e842">
#   <caption>Frosset laks, per år</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e842_level0_col0" class="col_heading level0 col0" >Gjennomsnitt</th>
#       <th id="T_5e842_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_5e842_level0_col2" class="col_heading level0 col2" >Std.avvik</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >År</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e842_level0_row0" class="row_heading level0 row0" >2000</th>
#       <td id="T_5e842_row0_col0" class="data row0 col0" >37.44</td>
#       <td id="T_5e842_row0_col1" class="data row0 col1" >37.14</td>
#       <td id="T_5e842_row0_col2" class="data row0 col2" >3.54</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row1" class="row_heading level0 row1" >2001</th>
#       <td id="T_5e842_row1_col0" class="data row1 col0" >26.96</td>
#       <td id="T_5e842_row1_col1" class="data row1 col1" >28.34</td>
#       <td id="T_5e842_row1_col2" class="data row1 col2" >3.90</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row2" class="row_heading level0 row2" >2002</th>
#       <td id="T_5e842_row2_col0" class="data row2 col0" >23.02</td>
#       <td id="T_5e842_row2_col1" class="data row2 col1" >23.80</td>
#       <td id="T_5e842_row2_col2" class="data row2 col2" >2.69</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row3" class="row_heading level0 row3" >2003</th>
#       <td id="T_5e842_row3_col0" class="data row3 col0" >23.65</td>
#       <td id="T_5e842_row3_col1" class="data row3 col1" >23.94</td>
#       <td id="T_5e842_row3_col2" class="data row3 col2" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row4" class="row_heading level0 row4" >2004</th>
#       <td id="T_5e842_row4_col0" class="data row4 col0" >24.50</td>
#       <td id="T_5e842_row4_col1" class="data row4 col1" >24.44</td>
#       <td id="T_5e842_row4_col2" class="data row4 col2" >1.48</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row5" class="row_heading level0 row5" >2005</th>
#       <td id="T_5e842_row5_col0" class="data row5 col0" >27.10</td>
#       <td id="T_5e842_row5_col1" class="data row5 col1" >26.49</td>
#       <td id="T_5e842_row5_col2" class="data row5 col2" >2.61</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row6" class="row_heading level0 row6" >2006</th>
#       <td id="T_5e842_row6_col0" class="data row6 col0" >35.80</td>
#       <td id="T_5e842_row6_col1" class="data row6 col1" >34.58</td>
#       <td id="T_5e842_row6_col2" class="data row6 col2" >5.34</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row7" class="row_heading level0 row7" >2007</th>
#       <td id="T_5e842_row7_col0" class="data row7 col0" >27.26</td>
#       <td id="T_5e842_row7_col1" class="data row7 col1" >27.42</td>
#       <td id="T_5e842_row7_col2" class="data row7 col2" >2.04</td>
#     </tr>
#     <tr>
#       <th id="T_5e842_level0_row8" class="row_heading level0 row8" >2008</th>
#       <td id="T_5e842_row8_col0" class="data row8 col0" >28.62</td>
#  Statistikk per sesong for fersk laks:
# <style type="text/css">
# #T_9abc3 th {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_9abc3  td {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_9abc3 th {
#   background-color: #f0f0f0;
#   text-align: center;
# }
# #T_9abc3 caption {
#   caption-side: top;
#   font-size: 16px;
#   margin-bottom: 10px;
# }
# #T_9abc3_row0_col0 {
#   background-color: #369f54;
#   color: #f1f1f1;
# }
# #T_9abc3_row0_col1, #T_9abc3_row1_col0, #T_9abc3_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9abc3_row0_col2 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_9abc3_row1_col1 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_9abc3_row2_col0 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_9abc3_row2_col1 {
#   background-color: #1d8640;
#   color: #f1f1f1;
# }
# #T_9abc3_row2_col2 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_9abc3_row3_col0, #T_9abc3_row3_col1, #T_9abc3_row3_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_9abc3">
#   <caption>Fersk laks, per sesong</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9abc3_level0_col0" class="col_heading level0 col0" >Gjennomsnitt</th>
#       <th id="T_9abc3_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_9abc3_level0_col2" class="col_heading level0 col2" >Std.avvik</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sesong</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9abc3_level0_row0" class="row_heading level0 row0" >Vinter</th>
#       <td id="T_9abc3_row0_col0" class="data row0 col0" >46.86</td>
#       <td id="T_9abc3_row0_col1" class="data row0 col1" >39.71</td>
#       <td id="T_9abc3_row0_col2" class="data row0 col2" >24.96</td>
#     </tr>
#     <tr>
#       <th id="T_9abc3_level0_row1" class="row_heading level0 row1" >Vår</th>
#       <td id="T_9abc3_row1_col0" class="data row1 col0" >49.94</td>
#       <td id="T_9abc3_row1_col1" class="data row1 col1" >39.65</td>
#       <td id="T_9abc3_row1_col2" class="data row1 col2" >26.90</td>
#     </tr>
#     <tr>
#       <th id="T_9abc3_level0_row2" class="row_heading level0 row2" >Sommer</th>
#       <td id="T_9abc3_row2_col0" class="data row2 col0" >44.50</td>
#       <td id="T_9abc3_row2_col1" class="data row2 col1" >38.50</td>
#       <td id="T_9abc3_row2_col2" class="data row2 col2" >20.25</td>
#     </tr>
#     <tr>
#       <th id="T_9abc3_level0_row3" class="row_heading level0 row3" >Høst</th>
#       <td id="T_9abc3_row3_col0" class="data row3 col0" >40.59</td>
#       <td id="T_9abc3_row3_col1" class="data row3 col1" >34.44</td>
#       <td id="T_9abc3_row3_col2" class="data row3 col2" >18.15</td>
#     </tr>
#   </tbody>
# </table>
#  Statistikk per sesong for frosset laks:
# <style type="text/css">
# #T_ea897 th {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_ea897  td {
#   padding: 8px 12px;
#   border: 1px solid #ddd;
#   color: #000;
# }
# #T_ea897 th {
#   background-color: #f0f0f0;
#   text-align: center;
# }
# #T_ea897 caption {
#   caption-side: top;
#   font-size: 16px;
#   margin-bottom: 10px;
# }
# #T_ea897_row0_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ea897_row0_col1 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_ea897_row0_col2 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_ea897_row1_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_ea897_row1_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_ea897_row1_col2 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_ea897_row2_col0, #T_ea897_row2_col1, #T_ea897_row2_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ea897_row3_col0, #T_ea897_row3_col1, #T_ea897_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ea897">
#   <caption>Frosset laks, per sesong</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea897_level0_col0" class="col_heading level0 col0" >Gjennomsnitt</th>
#       <th id="T_ea897_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_ea897_level0_col2" class="col_heading level0 col2" >Std.avvik</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sesong</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea897_level0_row0" class="row_heading level0 row0" >Vinter</th>
#       <td id="T_ea897_row0_col0" class="data row0 col0" >44.80</td>
#       <td id="T_ea897_row0_col1" class="data row0 col1" >40.07</td>
#       <td id="T_ea897_row0_col2" class="data row0 col2" >20.69</td>
#     </tr>
#     <tr>
#       <th id="T_ea897_level0_row1" class="row_heading level0 row1" >Vår</th>
#       <td id="T_ea897_row1_col0" class="data row1 col0" >46.97</td>
#       <td id="T_ea897_row1_col1" class="data row1 col1" >41.06</td>
#       <td id="T_ea897_row1_col2" class="data row1 col2" >21.30</td>
#     </tr>
#     <tr>
#       <th id="T_ea897_level0_row2" class="row_heading level0 row2" >Sommer</th>
#       <td id="T_ea897_row2_col0" class="data row2 col0" >47.31</td>
#       <td id="T_ea897_row2_col1" class="data row2 col1" >41.64</td>
#       <td id="T_ea897_row2_col2" class="data row2 col2" >21.37</td>
#     </tr>
#     <tr>
#       <th id="T_ea897_level0_row3" class="row_heading level0 row3" >Høst</th>
#       <td id="T_ea897_row3_col0" class="data row3 col0" >44.68</td>
#       <td id="T_ea897_row3_col1" class="data row3 col1" >39.56</td>
#       <td id="T_ea897_row3_col2" class="data row3 col2" >19.53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Denne visualiseringsmåten i tabeller gjør det enkelt å se hvilke år og sesonger det har vært høyest og lavest kilospris, samt når det har vært størst endringer. De lyseste verdiene i alle tabellene indikerer lave verdier, mens de mørkeste er de høyeste verdiene. Dette støtter de to tidligere plottene som sier at det har vært størst variasjon, prisendring og -økning de siste årene.
